# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies = movies.merge(credits,on='title')
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
# 3                     The Dark Knight Rises          7.6       9106    49026
# 4                               John Carter          6.1       2124    49529
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
# need to only keep the columns that are helpful for a content based recommender
# id
# title
# cast
# crew
# keywords
# overview
# genres
movies = movies[['id', 'title', 'cast', 'crew', 'keywords', 'overview', 'genres']]

# %%
movies.isnull().sum()
# Out:
# id          0
# title       0
# cast        0
# crew        0
# keywords    0
# overview    3
# genres      0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.isnull().sum()
# Out:
# id          0
# title       0
# cast        0
# crew        0
# keywords    0
# overview    0
# genres      0
# dtype: int64

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
# genres should be preprocessed to look like this
# ['Action', 'Adventure', 'ScienceFiction', 'Thriller']
import ast

# %%
def prep(obj):
    L = []
    for i in ast.literal_eval(obj):
        L.append(i["name"])
    return L

# %%
movies['genres'] = movies['genres'].apply(prep)
movies['keywords'] = movies['keywords'].apply(prep)

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]

# %%
def prep2(obj):
    L = []
    a = 0
    for i in ast.literal_eval(obj):
        if a != 3:
            L.append(i["name"])
            a += 1
        else:
            break
    return L

# %%
movies['cast'] = movies['cast'].apply(prep2)

# %%
def prep3(obj):
    L = []
    for i in ast.literal_eval(obj):
        if i["job"] == "Director":
            L.append(i["name"])
            break
    return L

# %%
movies['crew'] = movies['crew'].apply(prep3)

# %%
# overview needs to be split into keywords as well as split() is used
movies['overview'] = movies['overview'].apply(lambda x: x.split())

# %%
# need to remove spaces in all categories
# ex. chris pratt and chris hemsworth would both be "related" 
# in the current format but if they are written as
# chrispratt and chrishemsworth that issue isn't there
movies['genres'] = movies['genres'].apply(lambda x:[i.replace(" ", "") for i in x])
movies['cast'] = movies['cast'].apply(lambda x:[i.replace(" ", "") for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x:[i.replace(" ", "") for i in x])
movies['crew'] = movies['crew'].apply(lambda x:[i.replace(" ", "") for i in x])

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             cast                crew  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]

# %%
# creating "tags" with all the categories concatenated so that the movies can be compared
movies['tags'] = movies['overview'] + movies['keywords'] + movies['genres'] + movies['cast'] + movies['crew']

# %%
movie_data = movies[['id', 'title', 'tags']]

# %%
movie_data.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...

# %%
# list in tags should be a string
movie_data['tags'] = movie_data['tags'].apply(lambda x:" ".join(x))
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_17556\3025427521.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_data['tags'] = movie_data['tags'].apply(lambda x:" ".join(x))

# %%
movie_data.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
# all words in tags should be lowercase
movie_data['tags'] = movie_data['tags'].apply(lambda x: x.lower())
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_17556\973365434.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_data['tags'] = movie_data['tags'].apply(lambda x: x.lower())

# %%
# stop_words gets rid of and, or, in, etc
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 10000, stop_words = "english")

# %%
# this creates a vector with 10000 coordinates for each of the 4806 movies
vectors = cv.fit_transform(movie_data['tags']).toarray()

# %%
vectors.shape
# Out:
# (4806, 10000)

# %%
cv.get_feature_names()
# Out:
# C:\Users\krish\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['000',
#  '007',
#  '10',
#  '100',
#  '10th',
#  '11',
#  '12',
#  '12th',
#  '13',
#  '14',
#  '15',
#  '150',
#  '15th',
#  '16',
#  '16th',
#  '17',
#  '17th',
#  '18',
#  '1863',
#  '1890',
#  '18th',
#  '18thcentury',
#  '19',
#  '1910',
#  '1910s',
#  '1920',
#  '1920s',
#  '1927',
#  '1930s',
#  '1937',
#  '1940s',
#  '1941',
#  '1944',
#  '1945',
#  '1950',
#  '1950s',
#  '1955',
#  '1959',
#  '1960',
#  '1960s',
#  '1962',
#  '1964',
#  '1965',
#  '1967',
#  '1969',
#  '1970s',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1976',
#  '1977',
#  '1979',
#  '1980',
#  '1980s',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1990',
#  '1990s',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1999',
#  '19th',
#  '19thcentury',
#  '20',
#  '200',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2007',
#  '2008',
#  '2009',
#  '2011',
#  '2012',
#  '20th',
#  '21st',
#  '21stcentury',
#  '22nd',
#  '23',
#  '24',
#  '25',
#  '27',
#  '28',
#  '29',
#  '30',
#  '300',
#  '35',
#  '3d',
#  '40',
#  '400',
#  '47',
#  '50',
#  '500',
#  '51',
#  '60',
#  '60s',
#  '70',
#  '70s',
#  '7th',
#  '80',
#  'aaron',
#  'aaroneckhart',
#  'aarontaylor',
#  'abandoned',
#  'abandonment',
#  'abandons',
#  'abbiecornish',
#  'abby',
#  'abducted',
#  'abductions',
#  'abigailbreslin',
#  'abilities',
#  'ability',
#  'able',
#  'aboard',
#  'abortion',
#  'abrams',
#  'abroad',
#  'absence',
#  'absent',
#  'abuse',
#  'abused',
#  'abusive',
#  'academic',
#  'academy',
#  'accept',
#  'acceptance',
#  'accepted',
#  'accepts',
#  'access',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accidents',
#  'acclaim',
#  'acclaimed',
#  'accompanied',
#  'accompanies',
#  'accomplish',
#  'accomplished',
#  'account',
#  'accountant',
#  'accused',
#  'accuses',
#  'ace',
#  'achieve',
#  'acid',
#  'acquaintances',
#  'act',
#  'acting',
#  'action',
#  'actionhero',
#  'actions',
#  'activist',
#  'activists',
#  'activities',
#  'activity',
#  'actor',
#  'actors',
#  'actress',
#  'acts',
#  'actual',
#  'actually',
#  'ad',
#  'ada',
#  'adam',
#  'adambrody',
#  'adamgarcia',
#  'adammckay',
#  'adams',
#  'adamsandler',
#  'adamscott',
#  'adamshankman',
#  'adapt',
#  'adaptation',
#  'adapted',
#  'add',
#  'addict',
#  'addicted',
#  'addiction',
#  'addition',
#  'addled',
#  'adds',
#  'adjust',
#  'admiral',
#  'admired',
#  'admit',
#  'admits',
#  'adolescence',
#  'adolescent',
#  'adolf',
#  'adolfhitler',
#  'adopt',
#  'adopted',
#  'adoption',
#  'adoptivefather',
#  'adopts',
#  'adorable',
#  'adrenaline',
#  'adrian',
#  'adrianlyne',
#  'adrienbrody',
#  'adrift',
#  'adult',
#  'adultanimation',
#  'adultery',
#  'adulthood',
#  'adults',
#  'advanced',
#  'advancement',
#  'advantage',
#  'adventure',
#  'adventurer',
#  'adventures',
#  'adventurous',
#  'adversary',
#  'advertisement',
#  'advertising',
#  'advice',
#  'affair',
#  'affairs',
#  'affect',
#  'affected',
#  'affection',
#  'affections',
#  'afflicted',
#  'affluent',
#  'afford',
#  'afghanistan',
#  'afraid',
#  'africa',
#  'african',
#  'africanamerican',
#  'afro',
#  'aftercreditsstinger',
#  'afterlife',
#  'aftermath',
#  'afternoon',
#  'age',
#  'aged',
#  'agedifference',
#  'agency',
#  'agenda',
#  'agent',
#  'agents',
#  'ages',
#  'aggressionbyanimal',
#  'aggressive',
#  'aging',
#  'ago',
#  'agree',
#  'agrees',
#  'ahead',
#  'aid',
#  'aidan',
#  'aidanquinn',
#  'aide',
#  'aided',
#  'aids',
#  'ailing',
#  'aim',
#  'aiming',
#  'air',
#  'airborne',
#  'aircraft',
#  'airforce',
#  'airline',
#  'airplane',
#  'airplanecrash',
#  'airport',
#  'aisle',
#  'aka',
#  'akshaykumar',
#  'al',
#  'alabama',
#  'alan',
#  'alanalda',
#  'alanarkin',
#  'alanrickman',
#  'alaska',
#  'alaskan',
#  'albert',
#  'albertbrooks',
#  'albertfinney',
#  'alcatraz',
#  'alcohol',
#  'alcoholabuse',
#  'alcoholic',
#  'alcoholism',
#  'aldous',
#  'alec',
#  'alecbaldwin',
#  'alecguinness',
#  'alejandroamenábar',
#  'alejandrogonzáleziñárritu',
#  'alex',
#  'alexander',
#  'alexanderpayne',
#  'alexanderskarsgård',
#  'alexandradaddario',
#  'alexandreaja',
#  'alexapenavega',
#  'alexia',
#  'alexisbledel',
#  'alexkendrick',
#  'alexpettyfer',
#  'alexproyas',
#  'alfie',
#  'alfonsocuarón',
#  'alfredhitchcock',
#  'alfredmolina',
#  'algeria',
#  'ali',
#  'alice',
#  'alicebraga',
#  'aliciasilverstone',
#  'aliciawitt',
#  'alien',
#  'alienated',
#  'alienation',
#  'aliencontact',
#  'alieninfection',
#  'alieninvasion',
#  'alienlife',
#  'alienplanet',
#  'aliens',
#  'alike',
#  'alilarter',
#  'alive',
#  'allegedly',
#  'allen',
#  'alliance',
#  'allied',
#  'allies',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'ally',
#  'alongside',
#  'alpacino',
#  'alpha',
#  'alps',
#  'alter',
#  'altered',
#  'altering',
#  'alternate',
#  'alternatedimension',
#  'alternatehistory',
#  'alternatereality',
#  'alternative',
#  'alvin',
#  'alyssa',
#  'alzheimer',
#  'amanda',
#  'amandabynes',
#  'amandapeet',
#  'amandaseyfried',
#  'amateur',
#  'amazing',
#  'amazon',
#  'ambassador',
#  'amber',
#  'amberheard',
#  'ambertamblyn',
#  'ambition',
#  'ambitions',
#  'ambitious',
#  'ambulance',
#  'ambush',
#  'ambushed',
#  'amelia',
#  'america',
#  'americaferrera',
#  'american',
#  'americanabroad',
#  'americancivilwar',
#  'americandream',
#  'americanfootball',
#  'americanfootballplayer',
#  'americans',
#  'amid',
#  'amidst',
#  'amnesia',
#  'amp',
#  'amsterdam',
#  'amusement',
#  'amusementpark',
#  'amusing',
#  'amy',
#  'amyadams',
#  'amyheckerling',
#  'amypoehler',
#  'amysmart',
#  'ana',
#  'anakin',
#  'analyst',
#  'anarchiccomedy',
#  'anarchist',
#  'ancient',
#  'ancientchina',
#  'ancientegypt',
#  'ancientgreece',
#  'ancientrome',
#  'ancientworld',
#  'anderson',
#  'andie',
#  'andiemacdowell',
#  'andrew',
#  'andrewadamson',
#  'andrewdavis',
#  'andrewfleming',
#  'andrewgarfield',
#  'andrewniccol',
#  'andrewstanton',
#  'android',
#  'andrzejbartkowiak',
#  'andy',
#  'andyfickman',
#  'andygarcía',
#  'andysamberg',
#  'andyserkis',
#  'andytennant',
#  'angel',
#  'angela',
#  'angelabassett',
#  'angeles',
#  'angelinajolie',
#  'angels',
#  'anger',
#  'anglee',
#  'angry',
#  'angst',
#  'animal',
#  'animalattack',
#  'animalhorror',
#  'animals',
#  'animated',
#  'animation',
#  'anime',
#  'anjelicahuston',
#  'ann',
#  'anna',
#  'annabellasciorra',
#  'annabelle',
#  'annafaris',
#  'annafriel',
#  'annakendrick',
#  'annasophiarobb',
#  'anne',
#  'annebancroft',
#  'annefletcher',
#  'annehathaway',
#  'anneheche',
#  'annemoss',
#  'annettebening',
#  'annie',
#  'annihilation',
#  'anniversary',
#  'announces',
#  'annual',
#  'anonymity',
#  'anonymous',
#  'answer',
#  'answers',
#  'ant',
#  'antarctic',
#  'antarctica',
#  'anthology',
#  'anthony',
#  'anthonyanderson',
#  'anthonyhopkins',
#  'anthonymackie',
#  'anthonyrusso',
#  'anthropomorphism',
#  'anti',
#  'antics',
#  'antihero',
#  'antique',
#  'antisemitism',
#  'antiterror',
#  'antoinefuqua',
#  'anton',
#  'antonio',
#  'antoniobanderas',
#  'antony',
#  'antonyelchin',
#  'anxiety',
#  'apart',
#  'apartheid',
#  'apartment',
#  'ape',
#  'apes',
#  'apocalypse',
#  'apocalyptic',
#  'apollo',
#  'appalachia',
#  'apparent',
#  'apparently',
#  'appear',
#  'appearance',
#  'appearances',
#  'appearing',
#  'appears',
#  'apple',
#  'applies',
#  'appointed',
#  'appreciate',
#  'apprentice',
#  'approach',
#  'approached',
#  'approaches',
#  'approaching',
#  'april',
#  'aquarium',
#  'arab',
#  'arabian',
#  'arbitrarylaw',
#  'arch',
#  'archaeologist',
#  'archenemy',
#  'archeology',
#  'archer',
#  'archery',
#  'architect',
#  'arctic',
#  'arduous',
#  'area',
#  'aren',
#  'arena',
#  'argument',
#  'arise',
#  'arises',
#  'aristocrat',
#  'arizona',
#  'arkansas',
#  'arm',
#  'armageddon',
#  'armandassante',
#  'armed',
#  'armiehammer',
#  'arminmueller',
#  'armored',
#  'arms',
#  'armsdeal',
#  'armsdealer',
#  'armstrong',
#  'army',
#  'arnold',
#  'arnoldschwarzenegger',
#  'arranged',
#  'arrangedmarriage',
#  'arrangement',
#  'arranges',
#  'array',
#  'arrest',
#  'arrested',
#  'arrival',
#  'arrive',
#  'arrived',
#  'arrives',
#  'arriving',
#  'arrogance',
#  'arrogant',
#  'arson',
#  'art',
#  'artgallery',
#  'arthur',
#  'article',
#  'artifact',
#  'artificial',
#  'artificialintelligence',
#  'artist',
#  'artistic',
#  'artists',
#  'arts',
#  'artthief',
#  'asabutterfield',
#  'asgard',
#  'ash',
#  'ashes',
#  'ashley',
#  'ashleyjudd',
#  'ashleytisdale',
#  'ashtonkutcher',
#  'asia',
#  'asian',
#  'aside',
#  'ask',
#  'asked',
#  'asking',
#  'asks',
#  'asleep',
#  'aspects',
#  'asperger',
#  'aspirations',
#  'aspiring',
#  'ass',
#  'assassin',
#  'assassinate',
#  'assassination',
#  'assassins',
#  'assault',
#  'assaultrifle',
#  'assigned',
#  'assignment',
#  'assignments',
#  'assist',
#  'assistance',
#  'assistant',
#  'associate',
#  'associates',
#  'association',
#  'assortment',
#  'assume',
#  'assumes',
#  'asteroid',
#  'astronaut',
#  'astronauts',
#  'asylum',
#  'atheist',
#  'athlete',
#  'athletes',
#  'athletic',
#  'atlanta',
#  'atlantic',
#  'atlanticocean',
#  'atmosphere',
#  'atomegoyan',
#  'atomic',
#  'atomicbomb',
#  'attached',
#  'attack',
#  'attacked',
#  'attacking',
#  'attacks',
#  'attempt',
#  'attempted',
#  'attemptedmurder',
#  'attempting',
#  'attempts',
#  'attempttoescape',
#  'attend',
#  'attendant',
#  'attending',
#  'attends',
#  'attention',
#  'attic',
#  'attitude',
#  'attorney',
#  'attract',
#  'attracted',
#  'attracting',
#  'attraction',
#  'attractive',
#  'attracts',
#  'auction',
#  'auctioneer',
#  'audience',
#  'audiences',
#  'audition',
#  'audrey',
#  'audreytautou',
#  'august',
#  'aunt',
#  'austin',
#  'australia',
#  'australian',
#  'australianoutback',
#  'austria',
#  'austrian',
#  'author',
#  'authorities',
#  'authority',
#  'autism',
#  'autistic',
#  'auto',
#  'autobiographical',
#  'autobiography',
#  'automobileracing',
#  'autumn',
#  'available',
#  'avenge',
#  'avenger',
#  'average',
#  'aviation',
#  'aviv',
#  'avoid',
#  'avoiding',
#  'await',
#  'awaits',
#  'awake',
#  'awakened',
#  'awakening',
#  'awakens',
#  'award',
#  'awards',
#  'aware',
#  'awareness',
#  'away',
#  'awesome',
#  'awkward',
#  'awry',
#  'ax',
#  'axe',
#  'axel',
#  'babe',
#  'babies',
#  'baby',
#  'babysitter',
#  'bachelor',
#  'backdrop',
#  'backed',
#  'background',
#  'backgrounds',
#  'backpacker',
#  'backstage',
#  'backup',
#  'backwater',
#  'backwoods',
#  'backyard',
#  'bad',
#  'badboss',
#  'badluck',
#  'badly',
#  'badmother',
#  'bag',
#  'bahamas',
#  'bahari',
#  'bail',
#  'bailey',
#  'baker',
#  'balance',
#  'balboa',
#  'ball',
#  'ballet',
#  'balloon',
#  'baltimore',
#  'band',
#  'bandit',
#  'bandits',
#  'bands',
#  'bangkok',
#  'banished',
#  'bank',
#  'banker',
#  'banking',
#  'bankrobber',
#  'bankrobbery',
#  'banks',
#  'bannon',
#  'bar',
#  'barbara',
#  'barbarian',
#  'barbershop',
#  'barbrastreisand',
#  'barcelonaspain',
#  'barely',
#  'bargained',
#  'barn',
#  'barnes',
#  'barney',
#  'baron',
#  'barred',
#  'barriers',
#  'barry',
#  'barrylevinson',
#  'barrymore',
#  'barrypepper',
#  'barrysonnenfeld',
#  'bars',
#  'bart',
#  'base',
#  'baseball',
#  'based',
#  'basedonarticle',
#  'basedoncartoon',
#  'basedonchildren',
#  'basedoncomicbook',
#  'basedonfairytale',
#  'basedonfilm',
#  'basedongraphicnovel',
#  'basedonnovel',
#  'basedonplay',
#  'basedonshortstory',
#  'basedonstagemusical',
#  'basedontrueevents',
#  'basedontruestory',
#  'basedontvseries',
#  'basedonvideogame',
#  'basedonyoungadultnovel',
#  'basement',
#  'basis',
#  'basket',
#  'basketball',
#  'bat',
#  'bathroom',
#  'bathtub',
#  'batman',
#  'battalion',
#  'battle',
#  'battleassignment',
#  'battlefield',
#  'battles',
#  'battling',
#  'baxter',
#  'bay',
#  'bazluhrmann',
#  'bdsm',
#  'beach',
#  'beachhouse',
#  'beam',
#  'bear',
#  'beard',
#  'bearing',
#  'bears',
#  'beast',
#  'beasts',
#  'beat',
#  'beaten',
#  'beating',
#  'beatrice',
#  'beats',
#  'beau',
#  'beautiful',
#  'beautifulwoman',
#  'beauty',
#  'becca',
#  'beckons',
#  'becky',
#  'becominganadult',
#  'bed',
#  'bedroom',
#  'bee',
#  'beer',
#  'beethoven',
#  'befriends',
#  'began',
#  'beggar',
#  'begin',
#  'beginning',
#  'begins',
#  'beguilement',
#  'behavior',
#  'beheading',
#  'beijing',
#  'beings',
#  'belgium',
#  'belief',
#  'beliefs',
#  'believe',
#  'believed',
#  'believes',
#  'believing',
#  'bell',
#  'bella',
#  'bellas',
#  'belong',
#  'belongs',
#  'beloved',
#  'belt',
#  'ben',
#  'benaffleck',
#  'benchaplin',
#  'bending',
#  'beneath',
#  'benedictcumberbatch',
#  'benefit',
#  'benfoster',
#  'beniciodeltoro',
#  'benjamin',
#  'benjaminbratt',
#  'benkingsley',
#  'bennet',
#  'bennett',
#  'benstiller',
#  'bent',
#  'berlin',
#  'bernie',
#  'berniemac',
#  'best',
#  'bestfriend',
#  'bestfriendsinlove',
#  'bet',
#  'beth',
#  'bethany',
#  'betrayal',
#  'betrayed',
#  'betrothed',
#  'bets',
#  'bettemidler',
#  'better',
#  'betty',
#  'bettythomas',
#  'beverly',
#  'beverlyhills',
#  'bianca',
#  'bias',
#  'bible',
#  'biblical',
#  'bickering',
#  'bicycle',
#  'bid',
#  'big',
#  'bigger',
#  'biggest',
#  'bigotry',
#  'bike',
#  'biker',
#  'bikers',
#  'bikini',
#  'bilbo',
#  'billcondon',
#  'billewoodruff',
#  'billhader',
#  'billion',
#  'billionaire',
#  'billmoseley',
#  'billmurray',
#  'billnighy',
#  'billpaxton',
#  'billpullman',
#  'billy',
#  'billybobthornton',
#  'billyconnolly',
#  'billycrudup',
#  'billycrystal',
#  'billywilder',
#  'bind',
#  'binoculars',
#  'bio',
#  'biographical',
#  'biography',
#  'biological',
#  'biologicalweapon',
#  'biologist',
#  'biology',
#  'biopic',
#  'bird',
#  'birdee',
#  'birth',
#  'birthday',
#  'bisexual',
#  'bisexuality',
#  'bishop',
#  'bit',
#  'bite',
#  'bitten',
#  'bitter',
#  'bitterness',
#  'bittersweet',
#  'bizarre',
#  'black',
#  'blackandwhite',
#  'blackhole',
#  'blackmagic',
#  'blackmail',
#  'blackout',
#  'blackpeople',
#  'blacksmith',
#  'blade',
#  'blake',
#  'blakelively',
#  'blame',
#  'blart',
#  'blast',
#  'blaxploitation',
#  'blazing',
#  'bleek',
#  'blind',
#  'blinddate',
#  'blindness',
#  'blindnessandimpairedvision',
#  'bliss',
#  'blizzard',
#  'block',
#  'blockbuster',
#  'blofeld',
#  'blog',
#  'blonde',
#  'blood',
#  'bloodsplatter',
#  'bloodthirsty',
#  'bloody',
#  'bloom',
#  'blossoms',
#  'blow',
#  'blowjob',
#  'blown',
#  'blows',
#  'blu',
#  'blue',
#  'blues',
#  'blunt',
#  ...]

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\krish\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: joblib in c:\users\krish\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\krish\anaconda3\lib\site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: tqdm in c:\users\krish\anaconda3\lib\site-packages (from nltk) (4.64.0)
# Requirement already satisfied: click in c:\users\krish\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: colorama in c:\users\krish\anaconda3\lib\site-packages (from click->nltk) (0.4.4)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# uses angular distance to compare movies where 0 is the least similar movie and 1 is the most similar or same movie
similarity = cosine_similarity(vectors)

# %%
similarity
# Out:
# array([[1.        , 0.07644708, 0.05096472, ..., 0.02111002, 0.02272727,
#         0.        ],
#        [0.07644708, 1.        , 0.05714286, ..., 0.02366905, 0.        ,
#         0.        ],
#        [0.05096472, 0.05714286, 1.        , ..., 0.02366905, 0.        ,
#         0.        ],
#        ...,
#        [0.02111002, 0.02366905, 0.02366905, ..., 1.        , 0.06333005,
#         0.04174829],
#        [0.02272727, 0.        , 0.        , ..., 0.06333005, 1.        ,
#         0.04494666],
#        [0.        , 0.        , 0.        , ..., 0.04174829, 0.04494666,
#         1.        ]])

# %%
def recommend(movie):
    # find the index of the movie given and access similarity[movie_index]
    # sort similarity[i] from highest to lowest similarity
    # need to keep index position even if it's sorted by using enumerate
    # lambda is used so that the sorting is based on the similarity not the index
    
    movie_index = movie_data[movie_data['title'] == movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:16]
    
    for i in movies_list:
        print(movie_data.iloc[i[0]].title)

# %%
recommend("The Avengers")
# Out:
# Avengers: Age of Ultron
# Captain America: Civil War
# Iron Man 3
# Iron Man
# Captain America: The First Avenger
# Captain America: The Winter Soldier
# Iron Man 2
# Ant-Man
# Guardians of the Galaxy
# X-Men
# Fantastic Four
# The Incredible Hulk
# X-Men: Apocalypse
# Thor: The Dark World
# X-Men: First Class

# %%
import pickle

# %%
pickle.dump(movie_data, open("movies.pkl", "wb"))

# %%
movie_data['title'].values
# Out:
# array(['Avatar', "Pirates of the Caribbean: At World's End", 'Spectre',
#        ..., 'Signed, Sealed, Delivered', 'Shanghai Calling',
#        'My Date with Drew'], dtype=object)

# %%
pickle.dump(movie_data.to_dict(), open("movie_dict.pkl", "wb"))

# %%
pickle.dump(similarity, open("similarity.pkl", "wb"))
